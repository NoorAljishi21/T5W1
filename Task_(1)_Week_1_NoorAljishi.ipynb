# %% [markdown]
# #Dataset Description

# %% [markdown]
# \
#
# ## The dataset contains information about road traffic accidents with the following columns:
#
# `Time`: Time of the accident
#
# `Day_of_week`: Day of the week when the accident occurred
#
# `Age_band_of_driver`: Age group of the driver
#
# `Sex_of_driver`: Gender of the driver
#
# `Educational_level`: Educational level of the driver
#
# `Vehicle_driver_relation`: Relationship of the driver to the vehicle
#
# `Driving_experience`: Driving experience of the driver
#
# `Type_of_vehicle`: Type of vehicle involved in the accident
#
# `Owner_of_vehicle`: Owner of the vehicle
#
# `Service_year_of_vehicle`: Service years of the vehicle
#
# `Area_accident_occured`: Area where the accident occurred
#
# `Lanes_or_Medians`: Lanes or medians at the accident site
#
# `Road_allignment`: Road alignment at the accident site
#
# `Types_of_Junction`: Type of junction at the accident site
#
# `Road_surface_type`: Type of road surface at the accident site
#
# `Road_surface_conditions`: Road surface conditions at the accident site
#
# `Light_conditions`: Light conditions at the time of the accident
#
# `Weather_conditions`: Weather conditions at the time of the accident
#
# `Type_of_collision`: Type of collision
#
# `Number_of_vehicles_involved`: Number of vehicles involved in the accident
#
# `Number_of_casualties`: Number of casualties in the accident
#
# `Vehicle_movement`: Movement of the vehicle during the accident
#
# `Casualty_class`: Class of casualty (driver, passenger, pedestrian)
#
# `Sex_of_casualty`: Gender of the casualty
#
# `Age_band_of_casualty`: Age group of the casualty
#
# `Casualty_severity`: Severity of the casualty
#
# `Work_of_casuality`: Occupation of the casualty
#
# `Fitness_of_casuality`: Fitness of the casualty
#
# `Pedestrian_movement`: Movement of the pedestrian
#
# `Cause_of_accident`: Cause of the accident
#
# `Accident_severity`: Severity of the accident

# %% [markdown]
# # Tasks

# %% [markdown]
# Importing Libraries

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ##1. Data Cleaning

# %% [markdown]
# ### Read the dataset

# %%
df=pd.read_csv('/content/Task (1) Dataset.csv')

# %%
df.head(10)
# Out:
#        Time Day_of_week Age_band_of_driver Sex_of_driver   Educational_level  \
# 0  17:02:00      Monday              18-30          Male   Above high school
# 1  17:02:00      Monday              31-50          Male  Junior high school
# 2  17:02:00      Monday              18-30          Male  Junior high school
# 3   1:06:00      Sunday              18-30          Male  Junior high school
# 4   1:06:00      Sunday              18-30          Male  Junior high school
# 5  14:15:00      Friday              31-50          Male                 NaN
# 6  17:30:00   Wednesday              18-30          Male  Junior high school
# 7  17:20:00      Friday              18-30          Male  Junior high school
# 8  17:20:00      Friday              18-30          Male  Junior high school
# 9  17:20:00      Friday              18-30          Male  Junior high school
#
#   Vehicle_driver_relation Driving_experience      Type_of_vehicle  \
# ...

# %%
df.tail(10)
# Out:
#            Time Day_of_week Age_band_of_driver Sex_of_driver  \
# 12306  17:10:00      Friday              18-30          Male
# 12307  17:10:00      Friday              31-50          Male
# 12308  17:10:00      Friday              18-30          Male
# 12309   9:05:00      Friday              31-50        Female
# 12310   9:05:00      Friday              18-30          Male
# 12311  16:15:00   Wednesday              31-50          Male
# 12312  18:00:00      Sunday            Unknown          Male
# 12313  13:55:00      Sunday            Over 51          Male
# 12314  13:55:00      Sunday              18-30        Female
# 12315  13:55:00      Sunday              18-30          Male
#
#         Educational_level Vehicle_driver_relation Driving_experience  \
# 12306  Junior high school                Employee              2-5yr
# 12307  Junior high school                Employee         Above 10yr
# 12308  Junior high school                Employee         Above 10yr
# ...

# %%
df.sample(5)
# Out:
#           Time Day_of_week Age_band_of_driver Sex_of_driver  \
# 2704  17:46:00     Tuesday            Over 51          Male
# 1684  21:05:00      Friday              18-30          Male
# 3443  10:25:00    Saturday              31-50          Male
# 896   11:55:00      Friday              31-50          Male
# 8403  20:20:00    Thursday              31-50          Male
#
#        Educational_level Vehicle_driver_relation Driving_experience  \
# 2704         High school                Employee              1-2yr
# 1684   Elementary school                   Owner             5-10yr
# 3443  Junior high school                   Owner         Above 10yr
# 896    Elementary school                Employee          Below 1yr
# 8403   Elementary school                Employee             5-10yr
#
#        Type_of_vehicle Owner_of_vehicle Service_year_of_vehicle  ...  \
# 2704               NaN            Owner                     NaN  ...
# ...

# %%
df.sample(10)
# Out:
#            Time Day_of_week Age_band_of_driver Sex_of_driver  \
# 11984   7:30:00   Wednesday              31-50          Male
# 9610   17:20:00      Friday              18-30          Male
# 4143    8:40:00     Tuesday              18-30          Male
# 10348  20:16:00      Sunday              31-50          Male
# 5292   10:40:00     Tuesday              18-30          Male
# 1293   17:16:00      Friday              18-30          Male
# 6017    8:40:00   Wednesday            Unknown        Female
# 660     9:32:00      Sunday              31-50          Male
# 5462    6:45:00     Tuesday              18-30          Male
# 11332  22:05:00     Tuesday            Unknown          Male
#
#         Educational_level Vehicle_driver_relation Driving_experience  \
# 11984                 NaN                Employee              1-2yr
# 9610    Elementary school                   Owner              1-2yr
# 4143    Elementary school                Employee          Below 1yr
# ...

# %%
df.sample(20)
# Out:
#            Time Day_of_week Age_band_of_driver Sex_of_driver  \
# 3119    6:47:00      Friday              18-30          Male
# 2120   18:00:00     Tuesday              18-30          Male
# 8635   20:25:00    Saturday              18-30          Male
# 9838   15:00:00    Thursday              18-30          Male
# 7647   13:54:00      Monday              31-50          Male
# 11280  23:25:00   Wednesday              18-30          Male
# 8911   23:30:00      Monday              18-30          Male
# 5219   21:34:00      Sunday            Unknown        Female
# 11335   7:00:00    Thursday              31-50          Male
# 137     5:24:00      Friday              31-50          Male
# 10507  15:30:00      Friday            Over 51          Male
# 228     9:25:00     Tuesday            Unknown        Female
# 3719    6:59:00   Wednesday            Over 51          Male
# 2447    7:30:00      Friday            Unknown          Male
# ...

# %% [markdown]
# ### Handle Missing Values

# %%
#data shape
df.shape
# Out:
# (12316, 32)

# %%
#data types
df.dtypes
# Out:
# Time                           object
# Day_of_week                    object
# Age_band_of_driver             object
# Sex_of_driver                  object
# Educational_level              object
# Vehicle_driver_relation        object
# Driving_experience             object
# Type_of_vehicle                object
# Owner_of_vehicle               object
# Service_year_of_vehicle        object
# Defect_of_vehicle              object
# Area_accident_occured          object
# Lanes_or_Medians               object
# Road_allignment                object
# Types_of_Junction              object
# Road_surface_type              object
# Road_surface_conditions        object
# Light_conditions               object
# Weather_conditions             object
# Type_of_collision              object
# Number_of_vehicles_involved     int64
# Number_of_casualties            int64
# Vehicle_movement               object
# Casualty_class                 object
# Sex_of_casualty                object
# ...

# %%
df.isnull().sum()
# Out:
# Time                              0
# Day_of_week                       0
# Age_band_of_driver                0
# Sex_of_driver                     0
# Educational_level               741
# Vehicle_driver_relation         579
# Driving_experience              829
# Type_of_vehicle                 950
# Owner_of_vehicle                482
# Service_year_of_vehicle        3928
# Defect_of_vehicle              4427
# Area_accident_occured           239
# Lanes_or_Medians                385
# Road_allignment                 142
# Types_of_Junction               887
# Road_surface_type               172
# Road_surface_conditions           0
# Light_conditions                  0
# Weather_conditions                0
# Type_of_collision               155
# Number_of_vehicles_involved       0
# Number_of_casualties              0
# Vehicle_movement                308
# Casualty_class                    0
# Sex_of_casualty                   0
# Age_band_of_casualty              0
# ...

# %%
print(df['Educational_level'].str.split().str[0].unique())
# Out:
# ['Above' 'Junior' nan 'Elementary' 'High' 'Unknown' 'Illiterate' 'Writing']

# %%
df['Educational_level'] = df['Educational_level'].replace('Unknown', np.nan)

# %%
df['Educational_level'] = df['Educational_level'].fillna(df['Educational_level'].mode().iloc[0])

# %%
print(df['Vehicle_driver_relation'].str.split().str[0].unique())
# Out:
# ['Employee' 'Unknown' 'Owner' nan 'Other']

# %%
df['Vehicle_driver_relation'].fillna('Unknown', inplace=True)

# %%
df['Vehicle_driver_relation'] = df['Vehicle_driver_relation'].replace('Unknown', np.nan)

# %%
df['Educational_level'] = df['Educational_level'].fillna(df['Educational_level'].mode().iloc[0])

# %%
print(df['Vehicle_driver_relation'].str.split().str[0].unique())
# Out:
# ['Employee' nan 'Owner' 'Other']

# %%
df['Vehicle_driver_relation'] = df['Vehicle_driver_relation'].replace('nan', np.nan)

# %%
print(df['Vehicle_driver_relation'].str.split().str[0].unique())
# Out:
# ['Employee' nan 'Owner' 'Other']

# %%
df['Driving_experience'] = df['Driving_experience'].fillna(df['Driving_experience'].mode().iloc[0])
df['Type_of_vehicle'] = df['Type_of_vehicle'].fillna(df['Type_of_vehicle'].mode().iloc[0])
df.dropna(subset=['Owner_of_vehicle'], inplace=True)
df['Defect_of_vehicle'] = df['Defect_of_vehicle'].fillna(df['Defect_of_vehicle'].mode().iloc[0])
df['Area_accident_occured'] = df['Area_accident_occured'].fillna(df['Area_accident_occured'].mode().iloc[0])
df.dropna(subset=['Lanes_or_Medians'], inplace=True)
df.dropna(subset=['Road_allignment'], inplace=True)

# %%
df.dropna(subset=['Vehicle_driver_relation'], inplace=True)

# %%
print(df['Service_year_of_vehicle'].str.split().str[0].unique())
# Out:
# ['5-10yrs' nan 'Above' '1-2yr' '2-5yrs' 'Unknown' 'Below']

# %%
df['Service_year_of_vehicle'] = df['Service_year_of_vehicle'].replace('Unknown', np.nan)
df['Service_year_of_vehicle'] = df['Service_year_of_vehicle'].fillna(df['Service_year_of_vehicle'].mode().iloc[0])

# %%
df.isnull().sum()
# Out:
# Time                              0
# Day_of_week                       0
# Age_band_of_driver                0
# Sex_of_driver                     0
# Educational_level                 0
# Vehicle_driver_relation           0
# Driving_experience                0
# Type_of_vehicle                   0
# Owner_of_vehicle                  0
# Service_year_of_vehicle           0
# Defect_of_vehicle                 0
# Area_accident_occured             0
# Lanes_or_Medians                  0
# Road_allignment                   0
# Types_of_Junction               798
# Road_surface_type               153
# Road_surface_conditions           0
# Light_conditions                  0
# Weather_conditions                0
# Type_of_collision               142
# Number_of_vehicles_involved       0
# Number_of_casualties              0
# Vehicle_movement                275
# Casualty_class                    0
# Sex_of_casualty                   0
# Age_band_of_casualty              0
# ...

# %%
print(df['Types_of_Junction'].str.split().str[0].unique())
# Out:
# ['No' 'Y' 'Crossing' 'O' 'Other' 'Unknown' 'T' 'X' nan]

# %%
df.dropna(subset=['Types_of_Junction'], inplace=True)
df.dropna(subset=['Road_surface_conditions'], inplace=True)
df.dropna(subset=['Type_of_collision'], inplace=True)

# %%
df['Work_of_casuality'] = df['Work_of_casuality'].fillna(df['Work_of_casuality'].mode().iloc[0])
df['Fitness_of_casuality'] = df['Fitness_of_casuality'].fillna(df['Fitness_of_casuality'].mode().iloc[0])

# %%
df.isnull().sum()
# Out:
# Time                             0
# Day_of_week                      0
# Age_band_of_driver               0
# Sex_of_driver                    0
# Educational_level                0
# Vehicle_driver_relation          0
# Driving_experience               0
# Type_of_vehicle                  0
# Owner_of_vehicle                 0
# Service_year_of_vehicle          0
# Defect_of_vehicle                0
# Area_accident_occured            0
# Lanes_or_Medians                 0
# Road_allignment                  0
# Types_of_Junction                0
# Road_surface_type              131
# Road_surface_conditions          0
# Light_conditions                 0
# Weather_conditions               0
# Type_of_collision                0
# Number_of_vehicles_involved      0
# Number_of_casualties             0
# Vehicle_movement               248
# Casualty_class                   0
# Sex_of_casualty                  0
# Age_band_of_casualty             0
# Casualty_severity                0
# ...

# %%
df.dropna(subset=['Road_surface_type'], inplace=True)
df.dropna(subset=['Vehicle_movement'], inplace=True)

# %%
df.isnull().sum()
# Out:
# Time                           0
# Day_of_week                    0
# Age_band_of_driver             0
# Sex_of_driver                  0
# Educational_level              0
# Vehicle_driver_relation        0
# Driving_experience             0
# Type_of_vehicle                0
# Owner_of_vehicle               0
# Service_year_of_vehicle        0
# Defect_of_vehicle              0
# Area_accident_occured          0
# Lanes_or_Medians               0
# Road_allignment                0
# Types_of_Junction              0
# Road_surface_type              0
# Road_surface_conditions        0
# Light_conditions               0
# Weather_conditions             0
# Type_of_collision              0
# Number_of_vehicles_involved    0
# Number_of_casualties           0
# Vehicle_movement               0
# Casualty_class                 0
# Sex_of_casualty                0
# Age_band_of_casualty           0
# Casualty_severity              0
# Work_of_casuality              0
# ...

# %% [markdown]
# ### Correct any inconsistent data entries.

# %%
print(df['Type_of_vehicle'].str.split().str[1].unique())
# Out:
# ['(>' nan '(41?100Q)' '(13?45' '(11?40Q)' 'lorry' '(12' 'up' 'horse'
#  'vehicle']

# %%
print(df['Driving_experience'].str.split().str[1].unique())
# Out:
# ['10yr' nan 'Licence' '1yr']

# %%
# Escaped special characters and correct format
replace_list = ['\\(>', 'nan', '\\(41\\?100Q\\)', '\\(13\\?45', '\\(11\\?40Q\\)', 'lorry', '\\(12', 'up', 'horse', 'vehicle']

# Replace specific substrings with nothing in the 'Type_of_vehicle' column
df['Type_of_vehicle'] = df['Type_of_vehicle'].replace(to_replace=replace_list, value='', regex=True)

# Display the unique values in the 'Type_of_vehicle' column after replacement
unique_types_of_vehicle = df['Type_of_vehicle'].unique()
unique_types_of_vehicle
# Out:
# array(['Public  45 seats)', 'Automobile', 'Lorry ', 'Public  seats)',
#        'Long ', 'Taxi', 'Pick  to 10Q', 'Stationwagen', 'Ridden ',
#        'Other', 'Bajaj', 'Turbo', 'Motorcycle', 'Special ', 'Bicycle'],
#       dtype=object)

# %%
print(df['Type_of_vehicle'].str.split().str[0].unique())
# Out:
# ['Public' 'Automobile' 'Lorry' 'Long' 'Taxi' 'Pick' 'Stationwagen'
#  'Ridden' 'Other' 'Bajaj' 'Turbo' 'Motorcycle' 'Special' 'Bicycle']

# %%
df['Type_of_vehicle'] = df['Type_of_vehicle'].replace(['10yr', 'nan', 'Licence', '1yr'], '', regex=True)

# %%
print(df['Service_year_of_vehicle'].str.split().str[1].unique())
# Out:
# [nan '10yr' '1yr']

# %%
df['Type_of_vehicle'] = df['Type_of_vehicle'].replace(['10yr', 'nan', '1yr'], '', regex=True)

# %%
print(df['Sex_of_driver'].str.split().str[0].unique())
# Out:
# ['Male' 'Female' 'Unknown']

# %% [markdown]
# ### Ensure data types are appropriate for each column.
#
# ---

# %%
df.dtypes
# Out:
# Time                           object
# Day_of_week                    object
# Age_band_of_driver             object
# Sex_of_driver                  object
# Educational_level              object
# Vehicle_driver_relation        object
# Driving_experience             object
# Type_of_vehicle                object
# Owner_of_vehicle               object
# Service_year_of_vehicle        object
# Defect_of_vehicle              object
# Area_accident_occured          object
# Lanes_or_Medians               object
# Road_allignment                object
# Types_of_Junction              object
# Road_surface_type              object
# Road_surface_conditions        object
# Light_conditions               object
# Weather_conditions             object
# Type_of_collision              object
# Number_of_vehicles_involved     int64
# Number_of_casualties            int64
# Vehicle_movement               object
# Casualty_class                 object
# Sex_of_casualty                object
# ...

# %%
df['Time'] = pd.to_datetime(df['Time'], format='%H:%M:%S').dt.strftime('%H:%M:%S')

# %%
df.dtypes
# Out:
# Time                           object
# Day_of_week                    object
# Age_band_of_driver             object
# Sex_of_driver                  object
# Educational_level              object
# Vehicle_driver_relation        object
# Driving_experience             object
# Type_of_vehicle                object
# Owner_of_vehicle               object
# Service_year_of_vehicle        object
# Defect_of_vehicle              object
# Area_accident_occured          object
# Lanes_or_Medians               object
# Road_allignment                object
# Types_of_Junction              object
# Road_surface_type              object
# Road_surface_conditions        object
# Light_conditions               object
# Weather_conditions             object
# Type_of_collision              object
# Number_of_vehicles_involved     int64
# Number_of_casualties            int64
# Vehicle_movement               object
# Casualty_class                 object
# Sex_of_casualty                object
# ...

# %% [markdown]
# ## 2. Exploratory Data Analysis (EDA)

# %% [markdown]
# ### Perform summary statistics on the dataset.

# %%
# Perform summary statistics on the dataset
summary_statistics = df.describe(include='all')

# Display the summary statistics
print(summary_statistics)
# Out:
#             Time Day_of_week Age_band_of_driver Sex_of_driver  \
# count       9623        9623               9623          9623
# unique      1055           7                  5             3
# top     15:30:00      Friday              18-30          Male
# freq          83        1575               3307          8936
# mean         NaN         NaN                NaN           NaN
# std          NaN         NaN                NaN           NaN
# min          NaN         NaN                NaN           NaN
# 25%          NaN         NaN                NaN           NaN
# 50%          NaN         NaN                NaN           NaN
# 75%          NaN         NaN                NaN           NaN
# max          NaN         NaN                NaN           NaN
#
#          Educational_level Vehicle_driver_relation Driving_experience  \
# count                 9623                    9623               9623
# unique                   6                       3                  7
# ...

# %% [markdown]
# ### Identify and analyze patterns in the data.

# %%
# Plotting the data
sex_counts = df['Sex_of_driver'].value_counts()
plt.figure(figsize=(8, 6))
sex_counts.plot(kind='bar', color=['blue', 'pink','green'])
plt.title('Number of Drivers by Sex')
plt.xlabel('Sex of Driver')
plt.ylabel('Count')
plt.xticks(rotation=0)

# Display the plot
plt.show()

# %%
driving_experience_counts = df['Driving_experience'].value_counts()

# Plotting the data
plt.figure(figsize=(10, 7))
driving_experience_counts.plot(kind='pie', autopct='%1.1f%%', startangle=140, colors=plt.cm.Paired.colors)
plt.title('Distribution of Driving Experience')

# Display the plot
plt.show()

# %%
sns.boxplot(df['Number_of_casualties'])
# Out:
# <Axes: ylabel='Number_of_casualties'>

# %% [markdown]
# ### Visualize the distribution of key variables (e.g., Age_band_of_driver, Type_of_vehicle).

# %%
plt.figure(figsize=(10, 6))
value_counts = df['Age_band_of_driver'].value_counts()
value_counts.plot(kind='bar', color='blue', alpha=0.7)
plt.title('Distribution of Age_band_of_driver')
plt.xlabel('Age_band_of_driver')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %%
plt.figure(figsize=(10, 6))
value_counts = df['Type_of_vehicle'].value_counts()
value_counts.plot(kind='bar', color='blue', alpha=0.7)
plt.title('Distribution of Type_of_vehicle')
plt.xlabel('Type_of_vehicle')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %% [markdown]
# ### Explore relationships between variables (e.g., Age_band_of_driver vs. Accident_severity).

# %%
print(df['Accident_severity'].str.split().str[1].unique())
# Out:
# ['Injury' 'injury']

# %%
df['Accident_severity'] = df['Accident_severity'].replace('injury','Injury',regex=True)

# %%
plt.figure(figsize=(10,6))
sns.barplot(x = 'Age_band_of_driver', y = 'Accident_severity',data=df)

plt.show()

# %% [markdown]
# ## 3. Data Visualization

# %% [markdown]
# * Ensure the visualizations are clear and informative.

# %% [markdown]
# ### Create visualizations to illustrate the findings from the EDA.

# %% [markdown]
# ### Use appropriate plots such as histograms, bar charts, pie charts, scatter plots, and heatmaps.

# %%
df.plot.hexbin(x='Number_of_vehicles_involved',y='Number_of_casualties',gridsize=28),
# Out:
# (<Axes: xlabel='Number_of_vehicles_involved', ylabel='Number_of_casualties'>,)

# %% [markdown]
# ## 4. Insights and Conclusions

# %% [markdown]
# * <h3>Summarize the key insights gained from the data analysis.<h3/>
# * <h3>Draw conclusions based on the patterns observed in the data.<h3/>

# %% [markdown]
# - Gender Imbalance: Male drivers dominate.
# - Experienced Drivers: Most have 5-10 years' experience.
# - Casualties: Typically 1-2 per incident, some severe cases.
# - Driver Age: Mainly 18-50 years.
# - Vehicle Involvement: Automobiles and lorries are most involved.
